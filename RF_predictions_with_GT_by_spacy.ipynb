# %%
import pandas as pd
import src as CoreEngine
from time import sleep

df = pd.read_csv('data/prs_issues.csv', delimiter='\a')
df.head()
# Out:
#    Issue_Number  PR_Number                                        Issue_Title  \
# 0         959.0         12         Cleanup entries: Rely on "field formatter"
# 1         155.0        172                        Consistent encoding strings
# 2         290.0        300                             SourceForge references
# 3         498.0        452               Open pdf file when clicking pdf icon
# 4         545.0        595  JabRef 3.0: ACM Fetcher: Cannot parse number o...
#
#                                           Issue_Body  \
# 0  The first two cleanups can be achieved using t...
# 1  JabRef's [current encoding list](https://githu...
# 2  In PR #286 I have replaced most references to ...
# 3                                                NaN
# 4  When I do a search in the ACM in JabRef (no ma...
#
#                                       Issue_Comments  \
# 0  All the points are already fixed in the latest...
# 1  I fully agree with what you write and just had...
# 2  http://jabref.sourceforge.net/journals/journal...
# 3  ... is working fine.\n\nSeriously, you expect ...
# 4  I can confirm this. I've started to see if I c...
#
#                                             PR_Title  \
# 0  BugFix for #959 "StringIndexOutOfBoundsExcepti...
# 1                               Fix encoding strings
# 2   Fix #290 by removing the suggested url and text
# 3                                   Revise maintable
# 4               Fixed #545 - ACM fetcher works again
#
#                                              PR_Body  PR_Comments  \
# 0  Fixed #959 "StringIndexOutOfBoundsException wi...          NaN
# 1                                         Fixes #155          NaN
# 2  Removes the reference to a missing file earlie...          NaN
# 3  Complete check and rewrite of MainTable and re...          NaN
# 4                   Fixed #545 and some PMD cleanup.          NaN
#
#      PR_Author_Name PR_Author_Username         PR_Closed_Date
# 0     Ingvar Jackal       IngvarJackal  07/16/14, 06:57:22 PM
# 1      Jörg Lenhard            lenhard  09/18/15, 02:21:46 PM
# 2  Oscar Gustafsson           oscargus  11/07/15, 07:48:52 PM
# 3   Matthias Geiger     matthiasgeiger  12/15/15, 10:39:22 AM
# 4  Oscar Gustafsson           oscargus  12/28/15, 12:58:31 AM

# %%
## this class will keep on changing tokens when one will have its limit exceeeded
class tokens():
    def __init__(self):
        self.token_list = [
            ''
        ]
        self.cur = 0
    
    def get_next(self) -> str:
        self.cur = (self.cur+1) % len(self.token_list)
        return self.token_list[self.cur]

# %%
tokens = tokens()
my_token = tokens.get_next()
my_token
# Out:
# ''

# %% [markdown]
# # Generate predictions

# %%
# drop issues where body is NaN, since RF needs body
df = df[ df["Issue_Body"].notna() ]

# %%
# get the prediction from random forest model from issue number, issue title, issue body
def get_prediction( i_no, i_title, i_body ):
    issue = CoreEngine.issue_class.Issue( i_no, i_title, i_body )
    
    db = CoreEngine.DatabaseManager(
        dbfile="./output/main.db",
        cachefile="./ai_result_backup.db",
        label_file="./data/subdomain_labels.json",
    )
    
    external_rf = CoreEngine.External_Model_Interface(
        '#no need of OPENAI API key',
        db,
        "./output/rf_model.pkl",
        "./data/domain_labels.json",
        "./data/subdomain_labels.json",
        "./data/formatted_domain_labels.json",
        "./output/cache",
        "./output/response_cache/" 
    )

    prediction_rf = external_rf.predict_issue(issue)

    return prediction_rf

# %%
# run at last
# df['RF_Predictions'] = df.apply( lambda x: 
#                                  get_prediction( x['Issue_Number'], 
#                                                  x['Issue_Title'], 
#                                                  x['Issue_Body'] )
#                                , axis=1)

# %%
df.head()
# Out:
#    Issue_Number  PR_Number                                        Issue_Title  \
# 0         959.0         12         Cleanup entries: Rely on "field formatter"
# 1         155.0        172                        Consistent encoding strings
# 2         290.0        300                             SourceForge references
# 4         545.0        595  JabRef 3.0: ACM Fetcher: Cannot parse number o...
# 5         599.0        600  Import from external database fails for 3.1 an...
#
#                                           Issue_Body  \
# 0  The first two cleanups can be achieved using t...
# 1  JabRef's [current encoding list](https://githu...
# 2  In PR #286 I have replaced most references to ...
# 4  When I do a search in the ACM in JabRef (no ma...
# 5  Hi,\n\nJust tried out 3.1.  Thank you for all ...
#
#                                       Issue_Comments  \
# 0  All the points are already fixed in the latest...
# 1  I fully agree with what you write and just had...
# 2  http://jabref.sourceforge.net/journals/journal...
# 4  I can confirm this. I've started to see if I c...
# 5  I guess I need to look a bit closer or have mo...
#
#                                             PR_Title  \
# 0  BugFix for #959 "StringIndexOutOfBoundsExcepti...
# 1                               Fix encoding strings
# 2   Fix #290 by removing the suggested url and text
# 4               Fixed #545 - ACM fetcher works again
# 5  Avoid ConcurrentModificationException when rea...
#
#                                              PR_Body  PR_Comments  \
# 0  Fixed #959 "StringIndexOutOfBoundsException wi...          NaN
# 1                                         Fixes #155          NaN
# 2  Removes the reference to a missing file earlie...          NaN
# 4                   Fixed #545 and some PMD cleanup.          NaN
# 5                                        Fixes #599           NaN
#
#      PR_Author_Name PR_Author_Username         PR_Closed_Date
# 0     Ingvar Jackal       IngvarJackal  07/16/14, 06:57:22 PM
# 1      Jörg Lenhard            lenhard  09/18/15, 02:21:46 PM
# 2  Oscar Gustafsson           oscargus  11/07/15, 07:48:52 PM
# 4  Oscar Gustafsson           oscargus  12/28/15, 12:58:31 AM
# 5      Jörg Lenhard            lenhard  12/29/15, 01:23:26 PM

# %%
df.to_csv( 'prs_issues_rf_predictions.csv', header = True, encoding = 'utf-8', index = False, sep = '\a' )

# %% [markdown]
# # Build the ground truth

# %%
import requests

def get_pr_files(owner: str, repo: str, pr_number: str, token: str = my_token):
    """
    Fetch filenames and their contents changed in a pull request
    Returns: list[tuple] containing: (filename, file_content) 
    """
    url = f"https://api.github.com/repos/{owner}/{repo}/pulls/{pr_number}/files"
    headers = {'Authorization': f'token {token}'} if token else {}

    response = requests.get(url, headers=headers)
    
    if response.status_code != 200:
        if response.status_code == 403:
            print("rate limit exceeded, change token")
            my_token = tokens.get_next()
            token = my_token
            response = requests.get(url, {'Authorization': f'token {token}'})
        else:
            raise Exception(f"Error fetching PR files: {response.status_code}")

    files_data = response.json()
    
    files = []
    for f in files_data:
        # only files ending in java
        if ( f['filename'].endswith('.java') ):
            # try getting the file contents
            fc_res = requests.get( f['raw_url'], headers=headers )

            # success
            if fc_res.status_code == 200:
                files.append(    ( f['filename'], fc_res.content )   )
            else:
                if  fc_res.status_code == 403:
                    print('rate limit exceeded, change token')
                    my_token = tokens.get_next()
                    token = my_token
                else:
                    print(f"could not get content of file: {f['filename']}. statuscode: {fc_res.status_code}")

    return files

# %%
#  needs filename of the java program -> return AST object
generate_ast = CoreEngine.generate_ast.generate_ast
# needs AST object -> parses AST. returns parse object
java_program = CoreEngine.java_ast.JavaProgram

def get_symbol_blob( pr_number, owner = 'jabref', repo = 'jabref', token = my_token ):
    """
    generates a symbol blob containing all the symbols in all files changed in 
    a pull request. returns the blob as string
    """
    # get the files changed and their contenets
    try:
        files = get_pr_files( owner, repo, pr_number, token )
    except Exception as e:
        print(e)
        return None

    all_symbols = ""
    
    for f in files:
        # generate ast from file blob
        ast = generate_ast( f[1] )
        prgm = java_program(ast)
        classes, functions = prgm.extract_classes_and_methods()
        
        all_symbols += '    ' + 'classes: ' + '    '.join(classes) +  'functions: ' + '    '.join(functions)

    return all_symbols if all_symbols else None

# %%
import numpy as np
import spacy
nlp = spacy.load("en_core_web_md")

def get_labels( pr_number: int, owner: str ='JabRef', repo: str = 'jabref', token: str = my_token ):
    """
        Generates symbol blob for a pull request. Compares it with all the domain and subdomain labels 
        using spacy similarity functions. Then generates the top 3 labels based on similarity scores. 
        Output them as list of labels(strings)
    """
    labels: List[str] = []
    
    try:
        symbol_blob = get_symbol_blob( pr_number, owner, repo, token )
    except Exception as e:
        print(e)
        return []

    if not symbol_blob:
        return []

    domain_path = "./data/domain_labels.json"
    subdomain_path = "./data/subdomain_labels.json"
    api_labels = CoreEngine.utils.read_jsonfile_into_dict(domain_path)
    sub_labels = CoreEngine.utils.read_jsonfile_into_dict(subdomain_path)

    domains_available = {}
    for item in api_labels["Items"]:
        domains_available[list(item.keys())[0]] = item[list(item.keys())[0]]

    base = nlp( symbol_blob )

    # store similarity score, domain name
    domain_scores = []
    
    for domain_label, desc_label in domains_available.items():
        cmp_str = f"{domain_label.lower()}: {desc_label.lower()}"
        domain_info = nlp( cmp_str )
        similarity_score = base.similarity( domain_info )
        domain_scores.append(   (similarity_score, domain_label) )

    # retain top 3 domains 
    domain_scores.sort( key=lambda x: x[0], reverse = True )
    domain_scores = domain_scores[:3]

    for score, domain in domain_scores:
        subdomains = sub_labels[domain]

        # there is a bug in the current pipeline, because of which 
        # the subdomain for 'Event Handling' is never predicted. Instead
        # the whole 'Event Handling' is returned as it is.
        if domain == "Event Handling":
            labels.append( domain )
            continue
            
        # only get the max subdomain score for this domain
        max_score = 0
        max_subdomain = None
        
        for sd in subdomains:
            cur_subdomain, cur_subdomain_info = list(sd.keys())[0], list(sd.values())[0]
            cmp_text = cur_subdomain + ': ' + cur_subdomain_info
            subdomain_info = nlp( cmp_text )
            score = base.similarity(subdomain_info)
            if score > max_score:
                max_score = score
                max_subdomain = cur_subdomain
            
        labels.append( f"{domain}-{max_subdomain}" )

    return labels

# %%
labels = get_labels(172)

# %%
labels
# Out:
# ['Databases-Database Security',
#  'Error Handling-Debugging Tools',
#  'Data Structure-Data Sorting']

# %%
df["Ground_Truth"] = df.apply( lambda x: get_labels( x["PR_Number"] ) , axis = 1 )
# Out:
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# list index out of range
# HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: /JabRef/jabref/raw/55c9e794e36af33972b059e8436669881979a695/src%2Fmain%2Fjava%2Forg%2Fjabref%2Fgui%2Fcustomentrytypes%2FEntryCustomizationDialog.java (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7f2a57095bb0>: Failed to resolve 'github.com' ([Errno -5] No address associated with hostname)"))
# list index out of range
# list index out of range
# list index out of range
# list index out of range

# %%
df.head()
# Out:
#    Issue_Number  PR_Number                                        Issue_Title  \
# 0         959.0         12         Cleanup entries: Rely on "field formatter"
# 1         155.0        172                        Consistent encoding strings
# 2         290.0        300                             SourceForge references
# 4         545.0        595  JabRef 3.0: ACM Fetcher: Cannot parse number o...
# 5         599.0        600  Import from external database fails for 3.1 an...
#
#                                           Issue_Body  \
# 0  The first two cleanups can be achieved using t...
# 1  JabRef's [current encoding list](https://githu...
# 2  In PR #286 I have replaced most references to ...
# 4  When I do a search in the ACM in JabRef (no ma...
# 5  Hi,\n\nJust tried out 3.1.  Thank you for all ...
#
#                                       Issue_Comments  \
# 0  All the points are already fixed in the latest...
# 1  I fully agree with what you write and just had...
# 2  http://jabref.sourceforge.net/journals/journal...
# 4  I can confirm this. I've started to see if I c...
# 5  I guess I need to look a bit closer or have mo...
#
#                                             PR_Title  \
# 0  BugFix for #959 "StringIndexOutOfBoundsExcepti...
# 1                               Fix encoding strings
# 2   Fix #290 by removing the suggested url and text
# 4               Fixed #545 - ACM fetcher works again
# 5  Avoid ConcurrentModificationException when rea...
#
#                                              PR_Body  PR_Comments  \
# 0  Fixed #959 "StringIndexOutOfBoundsException wi...          NaN
# 1                                         Fixes #155          NaN
# 2  Removes the reference to a missing file earlie...          NaN
# 4                   Fixed #545 and some PMD cleanup.          NaN
# 5                                        Fixes #599           NaN
#
#      PR_Author_Name PR_Author_Username         PR_Closed_Date  \
# 0     Ingvar Jackal       IngvarJackal  07/16/14, 06:57:22 PM
# 1      Jörg Lenhard            lenhard  09/18/15, 02:21:46 PM
# 2  Oscar Gustafsson           oscargus  11/07/15, 07:48:52 PM
# 4  Oscar Gustafsson           oscargus  12/28/15, 12:58:31 AM
# 5      Jörg Lenhard            lenhard  12/29/15, 01:23:26 PM
#
#                                         Ground_Truth
# 0  [Databases-Database Security, Data Structure-D...
# 1  [Databases-Database Security, Error Handling-E...
# 2  [Databases-Database Security, Error Handling-E...
# 4  [Databases-Database Security, Error Handling-E...
# 5  [Databases-Database Security, Error Handling-E...

# %%
# save data frame for backup
# df.to_csv( "ground_truth.csv", index=False, header=True, sep="\a", encoding="utf-8" )

# %%
# generate random forest predictions
df['RF_Predictions'] = df.apply( lambda x: 
                                 get_prediction( x['Issue_Number'], 
                                                 x['Issue_Title'], 
                                                 x['Issue_Body'] )
                               , axis=1)
# Out:
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_1873.0_Group names are matched wrong
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_1721.0_Wrong usage of BibEntry field `id`
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2370.0_Relevance and read status cells: double-click behavior inverted
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2011.0_Add cleanup for escaping comments
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2390.0_Integrity check shows wrongfully that institution is a biblatex only element
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2394.0_Group names including brackets and spaces do not filter group anymore in v3.8
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2426.0_Backslashes are repeatedly escaped on save in Content-Selectors
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2447.0_Timestamp settings might break EntryEditor
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2458.0_"\~" Escape Sequence Does Not Display Correctly in Entry Table
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2472.0_ACM fetcher adds junk to database
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2475.0_duplicate entries with "subdatabase on .aux file" tool and crossreferences
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2486.0_Force Shutdown after accepting external changes
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2251.0_Shortcut F8 not working
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2500.0_Entry preview: wrong display of apostrophe (treated as special character)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2509.0_Office 207 XML export Nunber + Pubstate
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2522.0_Not possible to save a database
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2431.0_Can download article by DOI but not title
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2534.0_Main window: author: compound names cut off even using {}
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2470.0_JabRef causes permanent discrete GPU usage
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2493.0_Correct capitalisation of 'biblatex'
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2095.0_Replace "Database" by "Library" in the translation
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2570.0_ArXiV fetcher returns wrong entries when DOI is not in catalog
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2574.0_Science Direct fetcher is broken
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2580.0_Editing keywords clears priority, ranking, quality and relevance
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2577.0_PDF importation freezes when filename contains a curly bracket
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2596.0_The JabRef goes mad after clicking `Enable saving actions` in database properties.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2355.0_F4 should open currently selected file
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2573.0_Integrate github plugins for automatic bug report
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2484.0_Jabref 3.8.1 can't connect to open office 4.1.3
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2660.0_Add an option to clear the log inside the error console
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2676.0_Filename field in file annotations tab is too small when filename exceeds length of field
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2698.0_Despite checked Listen to remote operation on port 6050 new jabref sessions are created upon using jabfox
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2687.0_The generated BibTeX keys of  two different imported entries are not unique?!!
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2664.0_Latex2Unicode Formatter: Captial letters after an underscore are wrapped in braces
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2859.0_MSBibEntry office xml import and (re-)export of yearAccessed monthAccessed dayAccessed
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2843.0_Bibliographic fields missing
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2917.0_Issue with java.lang.NullPointerException: Files
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2901.0_Keybinding Exception when doing CTRL+Z or SHIFT+ sth (but works)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2938.0_Deleting a file in the entry editor deletes the file on disk
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2932.0_Group information in new database not stored
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2960.0_Duplicate finder ignores book edition
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2970.0_Resizing of the window "Select files" does not scale properly
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3036.0_Jabref freezes when dragging entries to groups panel or moving entries within groups
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3067.0_Del key in search box deletes entry
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3075.0_Group names
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_1495.0_Group hierarchy lost when moving to BibEntry
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3080.0_Automatic Bug Report - 20170806233800 Unable to attach file
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3074.0_Adding from DOI does not generate timestamp
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3086.0_Changes in Source Tab are not saved correctly without switching to another tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3103.0_Source panel in Entry Editor is not updated correctly in some circumstances
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3101.0_Move to group works like add to group
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2718.0_Check integrity action filter should have an option to select none and all
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3136.0_Missing "Normalize to BibTeX name format"
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2539.0_Call for function: export the pdfs of all the selected entrys to a new folder
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3106.0_New gitignore config ignores lib folder
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3161.0_Protected terms/Add selected text  not bringing up previous lists
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3130.0_Several problems in the new entry editor
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3170.0_Undo in EntryEditor Source Tab leads to exception
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3190.0_Deleting a group via groups interface does not remove that group reference from BibTex source
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3208.0_Description of LinkedFiles is not synced to the bibtex code/database
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2471.0_SAO/NASA ADS Bibcode Web Search
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3280.0_When PDF file is highlighted without any comment, File annotations display "N/A", it is better to leave it empty
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3255.0_import: file open dialog should have "supported formates" filetype
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3294.0_Jabref freezes after merging of entries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3264.0_Unable to "open folder" in case of filename with spaces
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3307.0_Cannot resolve '\textendash', etc. when displaying article title
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3342.0_Exception in opening bib file
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2802.0_cite command is not employed
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3144.0_Journal abreviation and integrity check
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3346.0_Automatically set file links - shortcut F7 not working
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3376.0_4.0 Crossref Websearch fails with "Parser error"
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3391.0_Preferences: Metal Look and Feel is listed twice
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3347.0_NPE when saving new database with entries  (DatabaseChangeMonitor is null)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3311.0_Filepath saved on Windows does not open on Linux
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3389.0_[Fatal Error] :1:1: Content is not allowed in prolog.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3046.0_Duplicates of fields corrupt Entry Editor display
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3414.0_Error in SyncLang.py
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3485.0_Check Integrity: Linking to EntryEditor problems
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3490.0_PDF import is running outside of JavaFX Thread
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3500.0_Importing from the ACM Digital Library hangs after selection
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3359.0_key generator fails to parse colon
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3493.0_It should be possible to delete an attached file
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3491.0_Double click on an entry on file list should open the PDF
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3472.0_Default settings for filename format and autolink files don't play nice together.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3538.0_Custom data in Type field in techreport not stored
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3476.0_automatically added file link has absolute instead of relative path
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2852.0_Performance problems with new groups search/filter and large databases
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3576.0_missing dot in files exported
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3562.0_Library properties: no change but...
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3584.0_Deleting an entry causes NPE exception
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3356.0_LaTeX `\textit{..}` is not redered correctly in Main table
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3532.0_Selecting new entry causes editing panel to become corrupted and not accept input
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3112.0_Colouring item count in groups panel does not work reliably
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3596.0_NPE in ExportFactory prevents JabRef from starting
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3598.0_Disable autocomplete in the search field
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3605.0_Export dialog with unclear format list
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3145.0_Validation messages are displayed at wrong position
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3648.0_chaining of modifiers does not work (in all cases?)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3679.0_Delete from disk should not be default option/selected on DELETE in file tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3646.0_JabRef doesn't start if AutomaticKeywordGroup uses a semicolon as separator
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_938.0_BibTeXML vs. bibteXMP
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3613.0_Add cleanup operation that replaces ligatures
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2831.0_Run "Abbreviate journal names" in parallel
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3323.0_Jabref rewrites the entire journal list on addition
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3737.0_JabRef xjc gradle task fails due to outage of the library of congress
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3573.0_Gradle task localizationUpdate does not work
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3146.0_Menu bar at wrong position on Mac OS
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3757.0_Add *.* to the Import File Filter Dialog
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4086.0_timestamp field is not set when drag'n'drop is used to import files
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3923.0_Dropping a PDF onto the File entry in General is inconsistent with standard attach method
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3258.0_4.0 groups view: no automatic unfold while dragging
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4087.0_When drag and drop to copy pdf folder is created
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3754.0_No-GUI mode (--nogui) should not try to use DISPLAY
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3799.0_OSX: With maintable-beta, JOptionPane for the "load backup file"  on startup does not show up and freezes JabRef
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3796.0_JabRef throws exception when started in another language with missing fxml localization
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3818.0_Exception when trying to save linked file
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3815.0_Adjust eclipse style to intellij (line wrapping)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3811.0_Exception in Entry Editor (Braces don't match)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3870.0_Magnifier changes colors wrong
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3896.0_monthfiled in patent should be treated same as month
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3926.0_Removing a file  link at General when editing an entry can lead to errnoneous double removal
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3929.0_Fetcher messages misleading
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3928.0_Integrity check should not report Coorporate Authors as "Names are not in standard format"
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3930.0_IEEE transitions to HTTPS
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3269.0_4.0 Groups: fast access to View options
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3845.0_Changes to preferences are not saved
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3860.0_The `URL` column missed in the maintable beta version
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3966.0_Problems finding fulltext for IEEExplore
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3971.0_Add RFC Standard Fetcher
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3986.0_Unable to launch jabref 4.2 with overriden font settings
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3995.0_Still freezes on macOS High Sierra
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3973.0_Reimplement Tooltips in the URL Column
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4013.0_custom export filter cannot be used
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4014.0_Fetcher 'Title' removes all spaces
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4018.0_Problem with web search for ACM
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3419.0_Feature Request: OpenSSL for SQL
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4038.0_JabRef-4.2 CLI does not work
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4000.0_'Do not overwrite existing keys' does not work
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4070.0_discrete versus integrated graphics card on MacOS
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4093.0_Minimum required java version for JabRef 4.3 is higher than the most recent stable java release provided for consumers on Windows 10
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4098.0_Comments are not shown in entry preview
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4097.0_Ctrl+O should open the folder in the current directory of the bib file
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4104.0_Moving to the next entry while in entry editor no longer supported
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4115.0_Single word journal titles show up with an alert
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4120.0_Clean-up operation moves files from file-field to pdf-field and can afterwards no longer be opened directly from JabRef.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3859.0_Set better default windows size for maintable beta version
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3805.0_Can't use a dash after a formatter
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4201.0_Jabref 5.0dev does not respect the standard directory
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4202.0_The window for About Jabref is to small: the buttons at the bottom are afunctional
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4241.0_added file link has absolute instead of relative path
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4192.0_Search for Spin in comments and correct these comments to new approach
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4279.0_"Cannot open entry-edit-window issue" not a bug, just minimized window. Enhancement proposal
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4233.0_Nullpointerexception while merging entries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4072.0_Cannot add exclusions into `XMP-metadata`'s `XMP export privacy settings`
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4296.0_Import window freezes JabRef (Mac OS)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4305.0_Dropping a file on entry editor does nothing
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4307.0_Rename and move file throws file not found exception
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4315.0_Support for Docbook 5 export
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4322.0_Jabref 5.0-dev UI can't resize in Debian GNU/Linux testing (buster)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4224.0_Save sort-criteria of maintable across sessions
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3850.0_Default sorting of entry table is lost
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4222.0_Ctrl-E to toggle the entry editor
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4357.0_software stucks when choose browse in Find unlinked files
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4356.0_adding file to file field - automatically asking what to do?
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4348.0_JabRef hangs when trying to merge entries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3537.0_Paste entries into group bug
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_1019.0_Make Show Preferences Window searchable
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4417.0_autogenerate bibtex key not working
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_482.0_Add JabRef Setup Icon for the install4j installation procedures
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4422.0_Import pdf file into current library doesn't work in second time.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4438.0_Unable to start up Jabref
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4414.0_Moving entries bewtween groups doesn't work
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4113.0_Improve check for page numbers
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4544.0_Downloads from arxiv saved with wrong file suffix
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3189.0_Renaming a group via groups interface does not change the group name in the interface
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2181.0_Integrity checker should link to entries via reference
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4593.0_Overlapping font in "ID Type" field when adding DOI or ISBN etc
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4598.0_v5.0: duplicates window totally empty (except buttons at the bottom)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4600.0_New entry default cursor location
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4609.0_Preview not configurable
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4621.0_Remove Preview Style from the right list results in Divide by zero exception
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4622.0_Reset preferences throws not on FX Thread exception multiple times
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4570.0_#4365 is back: preview copy fails
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4591.0_Add check for books with first edition
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4641.0_Remove usage of TempDirectory extension from junit-pioneer
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4628.0_Can't save new content selectors
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4661.0_Some journals are not abbreviated correctly
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4614.0_BibTexKey Duplicate Check throws NPE
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4666.0_Main Menu: group & order menu items
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4667.0_Main Menu: change icons
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4668.0_Main Menu: change File tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4669.0_Main Menu: change Edit tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4670.0_Main Menu: change Library tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4671.0_Main Menu: change Quality tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4672.0_Main Menu: change Tools tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4673.0_Main Menu: change View tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4709.0_Handling of diacritics in bibtex key generator
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4703.0_Wrong newline format in Jabref 5.0
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4714.0_Preview copy leads to exception
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4655.0_Exporting to MS Office 2007 XML omits "von" part from author's last name
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4306.0_Disable rename when file has already right name
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4728.0_JabRef does not quit after saving changes.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4584.0_Toolbar icons and their layout need improvement
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4724.0_Wrong default filename format pattern
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4494.0_RIS export empty
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4474.0_Can't input Chinese characters in biblatex source
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4023.0_Multiple jabref instances with 4.3 maintable-beta while Port 6050 is checked
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4764.0_Entry Editor removes entries when in souce-code-field
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4754.0_IllegalArgumentException: The event name cannot be null or empty
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4762.0_Entry Editor only opens after opening Preferences dialog
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4785.0_Quality-> Find duplicates throws a spectacular error
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4786.0_External addition/removal of new entry causes NullPointerException in review dialog
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4789.0_Closing a library but not JabRef, the .sav file is not deleted, causing a "Backup found" message at the next opening
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4763.0_"open folder" causes java.lang.NullPointerException: null
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4687.0_Entry Editor: change Required Fields tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4805.0_Improvement: Add all messages shown also to event log
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4811.0_A simple "save" add six lines to the event log
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4817.0_Exception for cleanup rename pdf (Automatic Bug Report - 20190328110358)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4816.0_possible problem with RIS publication year
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4819.0_Convert AutoLinkFilesAction to JavafX
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4824.0_Switch to Search result hits in Preferences-Search
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4588.0_Backslashes in group search are erased from bib file after saving
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4820.0_The file import dialog does not react to "enter".
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4735.0_Non-existing aux file in group throws IOException
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3531.0_Custom Name Formatters are not found
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3905.0_Apple Java Extensions still needed?
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4345.0_Pubmed import should have quality check multiple times.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4873.0_Error creating new string constants
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4844.0_Direct file renaming
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4579.0_Changing column width in JabRef 5.0 prevents opening 4.3.1
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2419.0_Add Group - dialog: width is to small for text/font
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4911.0_Borderless program launch under Linux Mint
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4905.0_Error when opening a bibtex file with a entry containing and "id" field
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4864.0_AuthorList parse adds extra space if author middlename is abbrevatied without dot
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4932.0_Bibliography cannot be updated
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4940.0_Open recent library command yields many IllegalStateExceptions
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4490.0_ Looking up Full Text Document of multiple entries simultaneously.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4886.0_The ordering of columns in the main table was disabled?
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4913.0_Downloads from the arXiv are marked as HTML files instead of PDF
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4827.0_Too big error message
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3599.0_Disable extended help in the search field
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4977.0_Different font weights changing entry type
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4997.0_IEEXplore Online Fetcher not working
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5003.0_Missing icon in macOS Launchpad
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4991.0_Submenu to select push-application
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_674.0_Add a proper way to set external application for pushing
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3942.0_[WIP] Add External Application Selection to Preferences
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4368.0_ WIP Default External Application Push Function
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4440.0_Warn on empty entrykey (bibtexkey)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5019.0_"Set up general fields" character check not correct & alphabetical ordering
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5043.0_Handling of umlaut while copy and paste of entries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5028.0_Entry Editor: "Other fields"
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5023.0_Broken automatic file links
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5066.0_Entry editor: "Copy linked files"
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5045.0_crossref resolution does not comply with biblatex specification
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5128.0_Exception when importing unlinked local files
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5182.0_[WIP] Try to find the error of Travis CI
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5175.0_Gradle build does not work on a fresh repository clone
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5164.0_Modify columns in table view
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5152.0_ToolTip to explain color in the first column of table view
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5194.0_Latex citations search -  Missing citations
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5163.0_Journal and Year missing from bibliography
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5198.0_Uncaught exception in adding a new entry by DOI
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4845.0_Cut and Paste duplicates entry in original table
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4699.0_Mac OS X: Pasting bibtex entry creates duplicate entries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4836.0_Pasting Text Happens Twice
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5220.0_Exception when adding field formatter in cleanup entries dialog
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4612.0_General fields layout: url and doi missing
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5021.0_entry editor: select which fields to show wrapped
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5278.0_InvocationTargetException because of com.jfoenix trying to access classes which it is not allowed to in gradle run
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5261.0_Linking to Libre/OpenOffice fails because of classloader exception
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3142.0_The Group Panel is not updated when switching between certain libraries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4441.0_Incorrect count entry number
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4846.0_Cleared search is redone after switching library
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5327.0_Group Count shows the value of the other library
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_2857.0_Group membership not indicated by colour if JabRef is opened and entry is selected immediately
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5334.0_Uncaught exception when opening file that no longer exists from the "Recent libraries" list
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5333.0_Keyword groups with keywords that consist only of spaces are displayed in a strange way
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5348.0_ctrl+q  throws exception
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5254.0_The context menu for entries is gone
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5022.0_group view update missing when scrolling
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4868.0_Default colour of group symbol for new groups deviates from standard colour of group symbol of pre-existing database
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5349.0_Search triggers too soon when entering regex
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5359.0_Field "editor" appears twice in all book-type-entries after saving bibtex file
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5169.0_Exception when merging entries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4303.0_Jabfox not working with 5.0 dev
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4737.0_Register native messaging host also when user has no admin rights
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5084.0_Cursor jumps from Search to Entry window and overrides content
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5447.0_Action "Import into current library" is active without any open library
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5244.0_Suggestions for improving the entry preview
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5446.0_Uncaught Exception occurred in Thread[JavaFX Application Thread,5,main]
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5277.0_Displaced hover indicator in comboBox lists
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5035.0_Web search results highlights multiple lines when selecting entries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5458.0_JFXColorPicker not compatible with JDK12
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5452.0_Error in importing jstyles
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5069.0_Entry preview lose formating if search field is used
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5469.0_Uncaught exception on startup with a database
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5460.0_Entry editor: Keep it open as default
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5485.0_Crossref API parameter query.title deprecated
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5496.0_Blank input editor - Uncaught exception occured in Thread[JavaFX Application Thread,5,main]
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5502.0_Error installing jabref deb package in ubuntu: native messaging host is not a dir
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5508.0_Make it easier to import single entries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5449.0_Null error while writing XMP metadata
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5516.0_Dark Theme: Wrong font color for textfield text in merge window
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5332.0_Custom entry import dialog only appears on broken files and is empty with inherited JabRef settings
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5546.0_Link file (without copying) doesn't work
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5580.0_Problem with current installer: Installation path can no longer be specified
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5520.0_Add file associations when installing
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5626.0_Today's "master builds" .deb won't install (2919-11-17)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5257.0_Jabref reports inexistent changes
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5664.0_soft link for main file directory fails silently (linux edition)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3874.0_Look up fulltext documents does not link existing PDFs
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5661.0_Special columns are not displayed correctly
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5653.0_Import option "Copy, Rename, Link" behaviour in v5-dev
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5537.0_importBibtex imports to an untitled library in a new instance
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4800.0_Irritating jumping to the "default" display (Sort order) when closing Options
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5037.0_Multiscreen issue
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5645.0_medline import does not work
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5753.0_White line on screens scaled != 100%
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5708.0_Cutting some of the bibtexkey raises error: Bale13 -> Bal13
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5602.0_Gui tests are broken
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4719.0_Re-implement "Customize entry types" dialog
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5820.0_Error when messing up bibtex
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5816.0_Missing file extension for downloaed file
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5675.0_Counts of selected items
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5861.0_Making paths of linked files relative breaks urls
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5846.0_Changing settings in "Options" > "Manage external file types" has no effect
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5905.0_Changing entry type does not work when biblatex source is shown
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5897.0_Uncaught exception in search
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5821.0_Jabref5 Portable Linux
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5906.0_Changing entry type does not always work when biblatex source is not shown
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5899.0_Author name with special characters breaks JabRef
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5892.0_Searching for a DOI results in an ERROR
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5939.0_Exception when opening library from File History Menu
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5942.0_Opening a PDF blocks JabRef (under Ubuntu/Linux)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5275.0_Allow for deactivation of integrity check
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5474.0_Remove background command line window
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5604.0_Oversized Libray properties dialog
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5968.0_Group is lost if assigned to very bottom
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5561.0_Group badges don't update after assignment
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5935.0_JabRef switches on macOS to discrete graphics which is not necessary
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5510.0_Reordering Groups does not work after previous drag & drop
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5246.0_Improve citation styles code
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5622.0_Entry preview: Error while generating citation style
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5701.0_Untranslated strings
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6017.0_Emacs Keyboard shortcuts for data entry/editing
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5832.0_Title made of two sentences: Capitalization is OK, but warning is displayed
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6108.0_Empty field not checked in dialog for creation of keyword-search groups
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6066.0_Add a subgroup: a warning should not close the window
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6115.0_Inconsistent capitalisation of downloaded files
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6078.0_Icons from Material design icons not recognized
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6120.0_Fulltext file deleted when being renamed to the name differing just by letter case
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6038.0_Make preferences larger
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5529.0_Open PDF options
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6136.0_Outdated dependencies
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_818.0_Full text search for American Physical Society (APS) journals
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6338.0_Dialog "Customize Entry Types" - drag&drop not working - adding new field buggy
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6049.0_File / Import / Append library freezes JabRef
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6074.0_Add tooltips for all entry types
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6194.0_Allow basic markup syntax in the comments tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6042.0_Proposed enhancement: Make item count in groups panel an optional feature that can be turned off
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6170.0_Imported open office jstyle files disappear when re-starting JabRef (Windows10)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5740.0_[WIP] Added number of items found
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6229.0_Fetching from inspire
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_333.0_Code for icons
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6169.0_":PDF" will not show the pdf icon in the
# ...
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6934.0_In entry types editor selected field is not removed after first click
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6866.0_Preferences: Search: Many items are not found
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6867.0_Double key binding for inserting new TechReport and pulling changes from shared database
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6964.0_Cannot add special characters like curley brackets or copy/pase in Bibtex source entry
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6936.0_irregularly losing ability to edit data in biblatex source tab
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6796.0_Dark theme: Entry table: Header of index without the proper color
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6957.0_Enable Auto Sync per default for Open/LibeOffice
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6892.0_Key generator regex() function not handling character classes
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6848.0_Search for unlinked local files: "collapse all" button expands tree
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6974.0_Alternative serialization format as core data file (e.g. YAML in addition to BibTeX)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6890.0_Icon doesn't show in Start menu | JabRef.exe does not start (JRE15 issue)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6991.0_UI: two menus for "Manage external file types"
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6691.0_Groups: "All entries" not highlighted on start-up
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4947.0_Drag and drop PDF import not working
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6086.0_Adjust scaling of JabRef for high-resolution displays
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5866.0_Crash pango with italic characters
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6456.0_fetcher isbn exception when including linebreak
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7019.0_Add Cleanup for copying over physcial review article id as the page number (revtex)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7000.0_Nothing happens creating entry from specific ISBN
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6579.0_Custom export format biblatex date field to bibtex year, month and day ones.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6862.0_Fix shared database tests
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7032.0_Extra character added to bib field "file" when adding an arXiv article
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7068.0_The entry preview window does not load my customized visual theme
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6777.0_regexp search throws exception when entering slash
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7053.0_Saving new library still shows "untitled*" in the tab bar
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6431.0_Update gradle from 6.3 to 6.5.1
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7114.0_NPE in groups panel opening
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6622.0_file save does not work when editing bib code in entry editor
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6417.0_Improve responsiveness of library loading
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6791.0_Dark theme: Search: case sensitive is case insensitive (and vice-versa)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7108.0_Document Viewer do not show all pages
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6959.0_Exception when "pulling changes" from local database
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6869.0_Password for shared PostgreSQL database will not be remembered
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6394.0_Main table: Coloured group indicator for cited entries does not show up consistently anymore
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5777.0_Context menu of linked file not updated after downloading
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7176.0_Shared Databases: creating new entries does not work, importing existing libraries does
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7127.0_Additional Short DOI fatal exception cases: java.lang.IllegalArgumentException: <string> is not a valid DOI/Short
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7203.0_PdfContentImporter: java.lang.StringIndexOutOfBoundsException: String index out of range: 3
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3925.0_Integrity check should not list "abbreviation detected"
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6942.0_Regex of University Institution too broad for citekey generation
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7199.0_Chinese author of essay reference section displays extra space
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7200.0_Exception upon copy (org.jabref.preferences.PreferencesService.getFieldWriterPreferences())
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5833.0_"New Group" > "Specified keywords" > "Generate groups for author last names" not working properly
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7197.0_Modify the "Directory not found" alert to show a more descriptive path
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7237.0_Translation of Traditional Chinese
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7239.0_Export to MODS format fails (wrong dash in pages field)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7226.0_Style of checkboxes while searching in preferences
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7194.0_Move file to file directory ceased working
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7272.0_Application Dialogs Open on Wrong Display
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7177.0_Java Exception when trying to open the preferences with missing custom theme
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7291.0_Rendering/conversion of π in Abstract/preview panel
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7202.0_Add support to add an entry from zbmath.org via its zbMATH id
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7264.0_Missing Key Bindings
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4342.0_Finding files with non-alphabetical characters in title
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7344.0_Unhandled exception when searching with regular expression
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4508.0_export to Harvard/RTF incorrect when name contains (properly escaped) "and"
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7354.0_Field "urldate" does not become YearAccessed, MonthAccessed, DayAccessed when exporting to MSWord
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6840.0_Offer migration from special fields in keywords to special fields as fields
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6994.0_Menu View: Alt+ keyboard shortcuts do not work.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7356.0_Convert layout resources to new authors formatter
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7349.0_When typing a "-" after a long title into web search the application freezes
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7382.0_Dark Theme visibility of File path
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7085.0_Changing font size makes font size field too small
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7015.0_Secondary sorting: not working for some special fields
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7414.0_Keyboard shortcut for merging entries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7387.0_epsilon symbol in unicode-to-latex not supported
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6962.0_Adding simple "Copy" in addition to "Copy preview" to right-click menu of preview
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7058.0_Switch from FontAwesomeFX to Ikonli
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7415.0_Non valid number as font size results in an uncaught exception.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7437.0_Enhance bibliographic information with data from zbmath.org
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7420.0_Citation keys are always overwritten when importing through web search
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7454.0_Openoffice / Merge citations is a trap, Unmerge is missing
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3791.0_No order of items in content selectors
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7464.0_Drag-and-drop of a bib file generate a loop of exceptions
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7020.0_Error message before starting new entry from ID
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7452.0_PDF Downloader downloads HTML source code instead if no access
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_3607.0_Improve display of automatically found file links in editor
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6730.0_User interface: Simplify Select Entry type form
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6818.0_When enlarging JabRef window, columns shrink in width
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7517.0_UI: "Export order" --> "Save order"
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7515.0_Snap build fails
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7481.0_The "custom colors" window for group color selection loads theme partially
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7465.0_Double-click onto PDF in file list should just open the file
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5522.0_Dark theme: Visibility problems with current colouring scheme (group colouring and scroll bars)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7525.0_File renaming functions are greyed out (deactivated) for unclear reasons
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_4129.0_Replace default group icon by small circle
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7550.0_Monocolor for icons
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6851.0_Drag & drop of PDF: not on empty library
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7554.0_Duplicate groups in an input file are not detected
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7337.0_Custom web address for accessing articles through DOI
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7524.0_Column sort order not properly stored
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7590.0_Uncaught exception when long pages in key
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7366.0_Add duplicate count/progress to Possible Duplicates dialog
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5850.0_Journal abbreviations in UTF-8 not recognized
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7195.0_Unselect entries in the main table and opacity of disabled icon-buttons
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7016.0_Toggle of special fields does not work for sorted entries
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7616.0_SSLHandshakeException
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7660.0_Unable to download some arXiv links if the "eprint" field is missing
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6199.0_EndNote .xml import to JabRef: PDF links are not imported correctly.
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7351.0_new time field creation date - missing possibility to read other field names; missing backup of old information
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7606.0_Seaching for bibliographies and importing them triggers uncaught java.lang.IndexOutOfBoundsException
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_1018.0_Importing to the correct mode when searching (BibTeX vs biblatex)
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7305.0_RFC fetcher compatibility with drafts
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6267.0_DOI-Import-entries not converted to biblatex
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7346.0_Some shortcuts are not working
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7439.0_Shortcut ctrl+shift+A not working
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7395.0_Possible Duplicates - Bibkey Comparison
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_6966.0_Bulk Copy/Open files
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7710.0_Cleanup action: some fields in random order
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7716.0_Some more fields in random order
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7451.0_Saving library doesn't create .bib file but a file without ending
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_5804.0_Rewrite ACM fetcher, because of ACM web site changes
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7111.0_Citation key, make it possible for an empty field to fall back to a custom field
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7737.0_import hangs for ris files with "ER  - " field, also other bib files common from journal web sites
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7267.0_Citation key generation on large number of entries not showing up in Background Tasks
# Predict Issue Cache Miss - ./output/cache_rf_None_./output/rf_model.pkl_7768.0_Unittest: assure preamble parses with arbitrary brackets

# %%
df = df[df['Ground_Truth'].map(len) > 0] 
df = df[df['RF_Predictions'].map(len) > 0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 573 entries, 0 to 634
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Issue_Number        573 non-null    float64
#  1   PR_Number           573 non-null    int64
#  2   Issue_Title         573 non-null    object
#  3   Issue_Body          573 non-null    object
#  4   Issue_Comments      509 non-null    object
#  5   PR_Title            573 non-null    object
#  6   PR_Body             573 non-null    object
#  7   PR_Comments         0 non-null      float64
#  8   PR_Author_Name      533 non-null    object
#  9   PR_Author_Username  573 non-null    object
#  10  PR_Closed_Date      573 non-null    object
#  11  Ground_Truth        573 non-null    object
#  12  RF_Predictions      573 non-null    object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 62.7+ KB

# %%
# save data frame for backup
# df.to_csv( "ground_truth_with_RF_prediction.csv", index=False, header=True, sep="\a", encoding="utf-8" )

# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

mlb = MultiLabelBinarizer()
y_true_bin = mlb.fit_transform(df['Ground_Truth'])
y_pred_bin = mlb.transform(df['RF_Predictions'])
# Out:
# /home/kaku/.venv/lib64/python3.12/site-packages/sklearn/preprocessing/_label.py:900: UserWarning: unknown class(es) ['Application-Version Control', 'Data Structure-Search Algorithms', 'Databases-Backup and Recovery', 'Event Handling', 'Software Development and IT Operations-Configuration Management'] will be ignored
#   warnings.warn(

# %%
accuracy = accuracy_score(y_true_bin, y_pred_bin)
precision = precision_score(y_true_bin, y_pred_bin, average='micro')
recall = recall_score(y_true_bin, y_pred_bin, average='micro')
f1 = f1_score(y_true_bin, y_pred_bin, average='micro')

print(f"Subset Accuracy: {accuracy:.4f}")
print(f"Precision (micro): {precision:.4f}")
print(f"Recall (micro): {recall:.4f}")
print(f"F1 Score (micro): {f1:.4f}")
# Out:
# Subset Accuracy: 0.0000
# Precision (micro): 0.9298
# Recall (micro): 0.1233
# F1 Score (micro): 0.2178

# %%
print("\nClassification Report:")
print(classification_report(y_true_bin, y_pred_bin, target_names=mlb.classes_))
# Out:
# Classification Report:
#                                                           precision    recall  f1-score   support
#
#                         Computer Graphics-Visual Effects       0.00      0.00      0.00        11
#                              Data Structure-Data Sorting       0.93      0.40      0.56       527
#                              Databases-Database Security       0.00      0.00      0.00       527
#                                  Databases-Schema Design       0.00      0.00      0.00        38
#                           Error Handling-Debugging Tools       0.00      0.00      0.00        89
#                             Error Handling-Error Logging       0.00      0.00      0.00        10
#                        Error Handling-Exception Handling       0.00      0.00      0.00       384
#            Geographic Information System-Data Collection       0.00      0.00      0.00        15
#                    Geographic Information System-Mapping       0.00      0.00      0.00        18
#                            Language-Runtime Optimization       0.00      0.00      0.00         3
#                Natural Language Processing-Text Analysis       0.00      0.00      0.00        23
#                                   Search-Personalization       0.00      0.00      0.00        57
#                             Security-Intrusion Detection       0.00      0.00      0.00         2
#                                  Setup-Environment Setup       0.00      0.00      0.00         8
# Software Development and IT Operations-Automated Testing       0.00      0.00      0.00         7
#
#                                                micro avg       0.93      0.12      0.22      1719
#                                                macro avg       0.06      0.03      0.04      1719
#                                             weighted avg       0.29      0.12      0.17      1719
#                                              samples avg       0.37      0.12      0.18      1719
# /home/kaku/.venv/lib64/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/kaku/.venv/lib64/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
